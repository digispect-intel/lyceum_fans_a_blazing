# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# Загружаем Excel
df = pd.read_excel('merged_dataset_results.xlsx')

# Категориальные переменные — кодируем
categorical_cols = ['model_name', 'activation_function', 'model_type', 'prompt', 'device', 'source_device', 'gpu_name']
for col in categorical_cols:
    df[col] = LabelEncoder().fit_transform(df[col].astype(str))

# Фичи и цели
X = df.drop(columns=['runtime_sec', 'powerty_consumption', 'source_file'])  # убираем цели и лишнее
y_runtime = df['runtime_sec']
y_power = df['powerty_consumption']

# Делим на train/test
X_train, X_temp, y_runtime_train, y_runtime_temp, y_power_train, y_power_temp = train_test_split(
    X, y_runtime, y_power, test_size=0.2, random_state=42
)

# Отделяем финальный тест из временного набора
X_test, X_final, y_runtime_test, y_runtime_final, y_power_test, y_power_final = train_test_split(
    X_temp, y_runtime_temp, y_power_temp, test_size=0.1, random_state=42
)

print("Размеры:")
print("Train:", X_train.shape)
print("Test:", X_test.shape)
print("Final test:", X_final.shape)

onedrive_path = "/content/drive/MyDrive/OneDrive/ML_datasets/"

# Сохраняем тренировочный набор
train_df = pd.concat([X_train, y_runtime_train, y_power_train], axis=1)
train_df.to_excel(onedrive_path + "train_set.xlsx", index=False)

# Сохраняем тестовый набор (валидационный)
test_df = pd.concat([X_test, y_runtime_test, y_power_test], axis=1)
test_df.to_excel(onedrive_path + "test_set.xlsx", index=False)

# Сохраняем финальный тестовый набор
final_df = pd.concat([X_final, y_runtime_final, y_power_final], axis=1)
final_df.to_excel(onedrive_path + "final_test_set.xlsx", index=False)
# Out:
# Размеры:
# Train: (2182, 18)
# Test: (491, 18)
# Final test: (55, 18)
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-3-b40ef5d49bf2> in <cell line: 0>()
#      32 # Сохраняем тренировочный набор
#      33 train_df = pd.concat([X_train, y_runtime_train, y_power_train], axis=1)
# ---> 34 train_df.to_excel("datasets/train_set.xlsx", index=False)
#      35
#      36 # Сохраняем тестовый набор (валидационный)
#
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     331                     stacklevel=find_stack_level(),
#     332                 )
# --> 333             return func(*args, **kwargs)
#     334
#     335         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...
